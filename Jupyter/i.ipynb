# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from Data.data_fetch import DataFetch

data = DataFetch('SX7P_cleaned.csv')
pricing = data.get_pricing()
# Out:
# c:\Users\Owent\Desktop\CV\Statistical Arb\Data\data_fetch.py:14: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   self.returns = data.pct_change().dropna()

# %%
print(pricing)
len(pricing)
# Out:
#            ABN NA Equity  ACA FP Equity  AIBG ID Equity  AZA SS Equity  \
# Dates
# 2/5/2020         11.8992         13.045           2.508          98.85
# 2/6/2020         12.1057         13.315           2.520          98.80
# 2/7/2020         12.1419         13.440           2.500          98.50
# 2/10/2020        12.0876         13.395           2.364          99.60
# 2/11/2020        12.2361         13.490           2.344         101.00
# ...                  ...            ...             ...            ...
# 1/30/2025        16.3650         14.580           5.730         329.40
# 1/31/2025        16.2150         14.545           5.695         334.20
# 2/3/2025         15.9100         14.410           5.545         329.30
# 2/4/2025         15.9200         14.555           5.730         333.80
# 2/5/2025         15.8200         14.675           5.725         336.00
#
#            BAMI IM Equity  BARC LN Equity  BBVA SQ Equity  BCP PL Equity  \
# Dates
# ...

# %%
x = pricing.shift(1)[1:]
print(x)
# Out:
#            ABN NA Equity  ACA FP Equity  AIBG ID Equity  AZA SS Equity  \
# Dates
# 2/6/2020         11.8992         13.045           2.508          98.85
# 2/7/2020         12.1057         13.315           2.520          98.80
# 2/10/2020        12.1419         13.440           2.500          98.50
# 2/11/2020        12.0876         13.395           2.364          99.60
# 2/12/2020        12.2361         13.490           2.344         101.00
# ...                  ...            ...             ...            ...
# 1/30/2025        16.3150         14.470           5.680         320.90
# 1/31/2025        16.3650         14.580           5.730         329.40
# 2/3/2025         16.2150         14.545           5.695         334.20
# 2/4/2025         15.9100         14.410           5.545         329.30
# 2/5/2025         15.9200         14.555           5.730         333.80
#
#            BAMI IM Equity  BARC LN Equity  BBVA SQ Equity  BCP PL Equity  \
# Dates
# ...

# %%
for pair in pricing.columns:

    pricing[pair].plot()
# Out:
# <Axes: xlabel='Dates'>

# %%
pair = 'ABN NA Equity'

x = pricing[pair].rolling(window=20).std()
plt.plot(x)
